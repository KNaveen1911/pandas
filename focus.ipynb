# %%
import pandas as pd

df=pd.read_csv ("data/focus.csv")

# %%
df.head(5)
# Out:
#     model    year     price transmission mileage fuel type engine size  \
# 0   Focus  2016.0    £8,000       Manual     NaN    Petrol       0.999
# 1   Focus  2019.0   £13,400       Manual     NaN    Petrol       0.999
# 2   Focus  2019.0   £14,600       Manual     NaN    Petrol       1.498
# 3   Focus  2016.0    £9,450       Manual     NaN    Diesel        1.56
# 4   Focus  2015.0    £9,999       Manual     NaN    Diesel        1.56
#
#   mileage2 fuel type2 engine size2     reference
# 0   38,852        NaN          NaN  /ad/25451236
# 1   11,952        NaN          NaN  /ad/25466927
# 2   22,142        NaN          NaN  /ad/25484363
# 3   14,549        NaN          NaN  /ad/20444868
# 4    7,010        NaN          NaN  /ad/22551057

# %%
df.shape
# Out:
# (5604, 11)

# %%
df.isnull().sum()
# Out:
# model             56
# year             145
# price             56
# transmission      56
# mileage          875
# fuel type       3416
# engine size      101
# mileage2          95
# fuel type2       874
# engine size2     874
# reference         56
# dtype: int64

# %%
print(df.dropna(how="all"))
# Out:
#        model    year     price transmission mileage fuel type engine size  \
# 0      Focus  2016.0    £8,000       Manual     NaN    Petrol       0.999
# 1      Focus  2019.0   £13,400       Manual     NaN    Petrol       0.999
# 2      Focus  2019.0   £14,600       Manual     NaN    Petrol       1.498
# 3      Focus  2016.0    £9,450       Manual     NaN    Diesel        1.56
# 4      Focus  2015.0    £9,999       Manual     NaN    Diesel        1.56
# ...      ...     ...       ...          ...     ...       ...         ...
# 5599   Focus  2019.0   £18,745       Manual     NaN    Diesel           2
# 5600   Focus  2019.0   £16,350       Manual     NaN    Petrol           1
# 5601   Focus  2019.0   £16,850       Manual     NaN    Petrol           1
# 5602   Focus  2019.0   £17,310    Automatic     NaN    Petrol           1
# 5603   Focus  2019.0   £17,610    Automatic     NaN    Petrol           1
#
#      mileage2 fuel type2 engine size2     reference
# ...

# %%
print(df.dropna(thresh=8))
# Out:
#        model    year     price transmission mileage fuel type engine size  \
# 0      Focus  2016.0    £8,000       Manual     NaN    Petrol       0.999
# 1      Focus  2019.0   £13,400       Manual     NaN    Petrol       0.999
# 2      Focus  2019.0   £14,600       Manual     NaN    Petrol       1.498
# 3      Focus  2016.0    £9,450       Manual     NaN    Diesel        1.56
# 4      Focus  2015.0    £9,999       Manual     NaN    Diesel        1.56
# ...      ...     ...       ...          ...     ...       ...         ...
# 5599   Focus  2019.0   £18,745       Manual     NaN    Diesel           2
# 5600   Focus  2019.0   £16,350       Manual     NaN    Petrol           1
# 5601   Focus  2019.0   £16,850       Manual     NaN    Petrol           1
# 5602   Focus  2019.0   £17,310    Automatic     NaN    Petrol           1
# 5603   Focus  2019.0   £17,610    Automatic     NaN    Petrol           1
#
#      mileage2 fuel type2 engine size2     reference
# ...

# %%
df.model=df.model.fillna(df.model.mode())
df.year=df.year.fillna(df.year.mode())
df.price=df.price.fillna(df.price.mode())
df['fuel type']=df['fuel type'].fillna(df['fuel type'].mode())
df['fuel type2']=df['fuel type2'].fillna(df['fuel type2'].mode())
df['engine size2']=df['engine size2'].fillna(df['engine size2'].mode())

# %%
df.dropna()
# Out:
#        model    year     price transmission   mileage fuel type engine size  \
# 11     Focus  2015.0    £7,500       Manual    42,112        11         £20
# 13     Focus  2015.0    £9,500    Automatic    30,292        14        £165
# 25     Focus  2016.0   £14,250       Manual    40,696        26         £20
# 26     Focus  2017.0    £9,900    Automatic    31,821        12        £125
# 28     Focus  2017.0    £9,900       Manual    21,492        11         £20
# ...      ...     ...       ...          ...       ...       ...         ...
# 5552   Focus  2018.0   £12,500       Manual     7,677        14        £150
# 5554   Focus  2011.0    £6,750       Manual    48,000        19        £145
# 5563   Focus  2014.0    £5,995       Manual    36,500        16         £20
# 5565   Focus  2006.0    £1,495       Manual  1,05,000        15        £125
# 5585   Focus  2017.0   £14,000    Automatic     9,137        14        £125
#
#      mileage2 fuel type2 engine size2     reference
# ...

# %%
df.isnull().sum()
# Out:
# model             56
# year             145
# price             56
# transmission      56
# mileage          875
# fuel type       3416
# engine size      101
# mileage2          95
# fuel type2       874
# engine size2     874
# reference         56
# dtype: int64

# %%
df.to_csv("data/cleaned data/focus1.csv")
